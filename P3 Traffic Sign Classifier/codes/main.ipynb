# %%
# Load pickled data
import pickle
import matplotlib.pyplot as plt

# TODO: Fill this in based on where you saved the training and testing data

training_file = "test.p"
validation_file="valid.p"
testing_file = "train.p"

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(validation_file, mode='rb') as f:
    valid = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)
    
X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']

X_test, y_test = test['features'], test['labels']

# %%
signnames_file = "signnames.csv"
with open(signnames_file) as f:
    f.readline() # Strip the header
    tuples = [line.strip().split(',') for line in f]
    sign_names = {int(t[0]): t[1] for t in tuples}

# %%
import numpy as np
print('train='+str(X_train.shape))
print('test='+str(X_test.shape))
print('validate='+str(X_valid.shape))
# print(X_train.shape)
train_shape=X_train.shape
test_shape=X_test.shape
valid_shape=X_valid.shape
labels_number=len(np.unique(y_train))
labels_number
# Out:
# train=(12630, 32, 32, 3)
# test=(34799, 32, 32, 3)
# validate=(4410, 32, 32, 3)
# 43

# %%
### Replace each question mark with the appropriate value. 
### Use python, pandas or numpy methods rather than hard coding the results

# TODO: Number of training examples
n_train = train_shape[0]

# TODO: Number of validation examples
n_validation = valid_shape[0]

# TODO: Number of testing examples.
n_test = test_shape[0]

# TODO: What's the shape of an traffic sign image?
image_shape = (train_shape[1],test_shape[2])

# TODO: How many unique classes/labels there are in the dataset.
n_classes = labels_number

print("Number of training examples =", n_train)
print("Number of testing examples =", n_test)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
# Out:
# Number of training examples = 12630
# Number of testing examples = 34799
# Image data shape = (32, 32)
# Number of classes = 43

# %%
### Data exploration visualization code goes here.
### Feel free to use as many code cells as needed.
import matplotlib.pyplot as plt
# Visualizations will be shown in the notebook.
# %matplotlib inline
plt.imshow(X_train[1])

# %% [markdown]
# ### Pre-process the Data Set (normalization, grayscale, etc.)

# %% [markdown]
# I have processed the data using minmaxscalar as that was giving even better rresult

# %%
y_train.shape
# Out:
# (12630,)

# %%
X_train.shape
# Out:
# (12630, 32, 32, 3)

# %%
import pandas as pd

# %%
for (data, name) in [[y_train, "training"], [y_valid, "validation"], [y_test, "test"]]:
    df = pd.DataFrame({'label': data})
    counts = df.groupby(['label']).agg({'label': 'count'})
    counts.plot(kind='bar', title="counts of each sign in %s data" % name, figsize=(15,4), rot=0)
    plt.xlabel("sign")
    plt.show()
    
# Gather 5 Example images per label
examples_per_sign = 5
total = 0
example = {}
for (img,label) in zip(X_train, y_train):
    example.setdefault(label, [])
    if len(example[label]) < examples_per_sign:
        example[label].append(img)
        total += 1
    if total == labels_number * examples_per_sign:
        break;

for label in sorted(example.keys()):
    fig = plt.figure()
    print(sign_names[label])
    for i in range(examples_per_sign):
        plt.subplot(1,examples_per_sign,i+1)
        plt.imshow(example[label][i])
    plt.show()
# Out:
# Speed limit (20km/h)
# Speed limit (30km/h)
# Speed limit (50km/h)
# Speed limit (60km/h)
# Speed limit (70km/h)
# Speed limit (80km/h)
# End of speed limit (80km/h)
# Speed limit (100km/h)
# Speed limit (120km/h)
# No passing
# No passing for vehicles over 3.5 metric tons
# Right-of-way at the next intersection
# Priority road
# Yield
# Stop
# No vehicles
# Vehicles over 3.5 metric tons prohibited
# No entry
# General caution
# Dangerous curve to the left
# Dangerous curve to the right
# Double curve
# Bumpy road
# Slippery road
# Road narrows on the right
# Road work
# Traffic signals
# Pedestrians
# Children crossing
# Bicycles crossing
# Beware of ice/snow
# Wild animals crossing
# End of all speed and passing limits
# Turn right ahead
# Turn left ahead
# Ahead only
# Go straight or right
# Go straight or left
# Keep right
# Keep left
# Roundabout mandatory
# End of no passing
# End of no passing by vehicles over 3.5 metric tons

# %%
import seaborn as sns
sns.distplot(y_train,rug=True,color='y')

# %%
sns.distplot(y_test,rug=True,color='r')

# %%
sns.distplot(y_valid,rug=True,color='g')

# %%
# Normalisation of data
#cheecking maximum and minimum value of this
X_train_max=np.max(X_train)
X_test_max=np.max(X_test)
X_valid_max=np.max(X_valid)
print(X_train_max,X_test_max,X_valid_max)
X_train_min=np.min(X_train)
X_test_min=np.min(X_test)
X_valid_min=np.min(X_valid)
print(X_train_min,X_test_min,X_valid_min)
# Out:
# 1.0 1.0 1.0
# 0.0 0.0 0.0

# %%
plt.imshow(X_train[1])

# %%
#since maximum and minimum values are found to be 255 and 0 so
X_train=X_train/255.0
X_valid=X_valid/255.0
X_test=X_test/255.0

# %%
plt.imshow(X_train[1])

# %%
plt.imshow(X_test[0])

# %%
import cv2

# %% [markdown]
# # loading the model

# %%
import tensorflow
model1 = tensorflow.keras.models.load_model('newfolder')

# %%
import tensorflow as tf
from tensorflow import estimator,metrics,sigmoid,acos
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,MaxPool2D,Dropout,Flatten,Conv2D
from tensorflow.keras.activations import relu

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout

# %%
from pydot import *
import graphviz
# !conda install python-graphviz

# %%
import tensorflow as tf
import matplotlib.image as mpimg

# %%
a1=model1.predict_classes(X_test)

# %%
a1
# Out:
# array([41, 41, 41, ..., 25, 25, 25], dtype=int64)

# %%
from sklearn.metrics import classification_report

# %%
classif=classification_report(y_test,a1)

# %%
print(classif)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94       180
#            1       0.98      0.95      0.96      1980
#            2       0.97      0.96      0.96      2010
#            3       0.96      0.95      0.95      1260
#            4       0.93      0.98      0.95      1770
#            5       0.94      0.93      0.94      1650
#            6       0.88      0.98      0.93       360
#            7       0.97      0.97      0.97      1290
#            8       0.97      0.97      0.97      1260
#            9       1.00      0.98      0.99      1320
#           10       0.99      1.00      0.99      1800
#           11       0.94      0.84      0.89      1170
#           12       0.95      0.98      0.97      1890
#           13       0.96      1.00      0.98      1920
#           14       0.99      0.99      0.99       690
#           15       0.91      0.95      0.93       540
# ...

# %%
predicted=model1.predict_classes(X_train)

predicted1=model1.predict_classes(X_test)

predicted2=model1.predict_classes(X_valid)

# %%
from sklearn.metrics import accuracy_score

# %%
a0=accuracy_score(y_train,predicted)
a1=accuracy_score(y_test,predicted1)
a2=accuracy_score(y_valid,predicted2)
print(a0,a1,a2)
# Out:
# 0.9995249406175772 0.9439351705508779 0.9306122448979591

# %% [markdown]
# # Train accuracy 99.95% -> 100%
# # Test accuracry 94.4%
# # Valid Accuracy 93%

# %% [markdown]
# # Summary of the models

# %%
model1.layers

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 26, 26, 80)        64080
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 80)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 13, 13, 80)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 11, 11, 32)        23072
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 5, 32)          0
# ...

# %%
model1.get_config()
# Out:
# {'name': 'sequential',
#  'layers': [{'class_name': 'Conv2D',
#    'config': {'name': 'conv2d',
#     'trainable': True,
#     'batch_input_shape': [None, 32, 32, 3],
#     'dtype': 'float32',
#     'filters': 32,
#     'kernel_size': [3, 3],
#     'strides': [1, 1],
#     'padding': 'valid',
#     'data_format': 'channels_last',
#     'dilation_rate': [1, 1],
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None}},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'conv2d_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 80,
#     'kernel_size': [5, 5],
#     'strides': [1, 1],
#     'padding': 'valid',
#     'data_format': 'channels_last',
# ...

# %% [markdown]
# tuner = Hyperband(
#     build_models,
#     objective='val_accuracy',
#     max_epochs=5,
#     hyperband_iterations=2)

# %% [markdown]
# # Predicting top 5 softmax.
# Since it is only 5 so i am doing it manually

# %%
import cv2

# %%
def preprocessing(img_array,dim=(32,32)):
    arr=np.array([])
    for i in img_array:
        i=cv2.resize(i1,dim, interpolation = cv2.INTER_AREA)
        arr=np.append(arr,i)
    return arr

# %%
i1=cv2.imread('im1.png')
i2=cv2.imread('im2.png')
i3=cv2.imread('im3.png')
i4=cv2.imread('im4.png')
i5=cv2.imread('im5.png')
dim=(32,32)

# %%
i1=i1/255.0
i2=i2/255.0
i3=i3/255.0
i4=i4/255.0
i5=i5/255.0

# %%
i1=cv2.resize(i1,dim, interpolation = cv2.INTER_AREA)
i2=cv2.resize(i2,dim, interpolation = cv2.INTER_AREA)
i3=cv2.resize(i3,dim, interpolation = cv2.INTER_AREA)
i4=cv2.resize(i4,dim, interpolation = cv2.INTER_AREA)
i5=cv2.resize(i5,dim, interpolation = cv2.INTER_AREA)

# %%
i11=i1.reshape((1,32,32,3))
i12=i2.reshape((1,32,32,3))
i13=i3.reshape((1,32,32,3))
i14=i4.reshape((1,32,32,3))
i15=i5.reshape((1,32,32,3))

# %%
p1=model1.predict(i11)
p2=model1.predict(i12)
p3=model1.predict(i13)
p4=model1.predict(i14)
p5=model1.predict(i15)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pred=np.array([p1,p2,p3,p4,p5])

# %%
p11=np.argsort(p1,axis=1)[:,-5:]
p12=np.argsort(p2,axis=1)[:,-5:]
p13=np.argsort(p3,axis=1)[:,-5:]
p14=np.argsort(p4,axis=1)[:,-5:]
p15=np.argsort(p5,axis=1)[:,-5:]

# %%
pred_5=np.array([p11,p12,p13,p14,p15])

# %%
df=pd.read_csv('signnames.csv')

# %%
b=[]
for i in p11[0]:
    a=df[df['ClassId']==i]
#     print(a)
    a=a.values[0][1]
    c=p1[0][i]
    b.append([a,c])

# %%
d=[]
for i in p12[0]:
    a=df[df['ClassId']==i]
#     print(a)
    a=a.values[0][1]
    c=p2[0][i]
    d.append([a,c])

# %%
e=[]
for i in p13[0]:
    a=df[df['ClassId']==i]
#     print(a)
    a=a.values[0][1]
    c=p3[0][i]
    e.append([a,c])

# %%
f=[]
for i in p14[0]:
    a=df[df['ClassId']==i]
#     print(a)
    a=a.values[0][1]
    c=p4[0][i]
    f.append([a,c])

# %%
g=[]
for i in p15[0]:
    a=df[df['ClassId']==i]
#     print(a)
    a=a.values[0][1]
    c=p5[0][i]
    g.append([a,c])

# %%
print(b[0][1])
# Out:
# 2.3171337e-17

# %%
name=b[0][0]
prob=b[0]

# %%
plt.imshow(i1)

# %%
b
# Out:
# [['Traffic signals', 2.3171337e-17],
#  ['Speed limit (50km/h)', 7.392017e-15],
#  ['Speed limit (20km/h)', 2.280922e-14],
#  ['Speed limit (70km/h)', 9.938535e-14],
#  ['Speed limit (30km/h)', 1.0]]

# %%
plt.imshow(i2)

# %%
d
# Out:
# [['Speed limit (30km/h)', 1.5306637e-22],
#  ['Ahead only', 5.2261523e-22],
#  ['Turn left ahead', 6.6438794e-22],
#  ['Roundabout mandatory', 7.694055e-21],
#  ['Turn right ahead', 1.0]]

# %%
plt.imshow(i3)

# %%
e
# Out:
# [['Speed limit (100km/h)', 5.3222666e-06],
#  ['Speed limit (120km/h)', 1.0624367e-05],
#  ['Speed limit (60km/h)', 1.3820942e-05],
#  ['Speed limit (50km/h)', 0.000772773],
#  ['Speed limit (80km/h)', 0.9991961]]

# %%
plt.imshow(i4)

# %%
f
# Out:
# [['Turn left ahead', 6.584047e-18],
#  ['Traffic signals', 6.945318e-16],
#  ['Ahead only', 2.4448854e-13],
#  ['Keep left', 5.3049947e-13],
#  ['Turn right ahead', 1.0]]

# %%
plt.imshow(i5)

# %%
g
# Out:
# [['Right-of-way at the next intersection', 3.9416917e-20],
#  ['Bumpy road', 4.1177044e-20],
#  ['Keep right', 4.5208295e-19],
#  ['Wild animals crossing', 1.1694021e-18],
#  ['Road work', 1.0]]
